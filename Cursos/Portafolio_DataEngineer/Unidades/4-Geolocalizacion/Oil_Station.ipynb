# %% [markdown]
# <h1><center>Geocoding Api's</center></h1>
#
# ## Google API
#
# * [**Google_Free_Tier**](https://cloud.google.com/free/?utm_source=google&utm_medium=cpc&utm_campaign=latam-LATAM-all-es-dr-AKWS-all-all-trial-p-dr-1011454-LUAC0013610&utm_content=text-ad-none-any-DEV_c-CRE_540885993580-ADGP_Hybrid%20%7C%20BKWS%20-%20PHR%20%7C%20Txt%20~%20Management-Tools_Console-KWID_43700065922071537-kwd-651816590614&utm_term=KW_google%20console-ST_Google%20Console&gclid=Cj0KCQjwnbmaBhD-ARIsAGTPcfWVMlJlTFywFNaAo8P-MNL4_gM6L7yucqAQ37xg1AIEHzpAzF_kkAoaAsszEALw_wcB&gclsrc=aw.ds)
# * [**Google_Api_Pricing**](https://mapsplatform.google.com/pricing/)
#
# ## HERE Platform
#
# * [**Here_Register**](https://platform.here.com/sign-up?step=verify-identity&aid=www.here.com-start-building)
# * [**Here_Princing**](https://www.here.com/pricing)
# * [**Geocoding_Documentation**](https://developer.here.com/documentation/geocoding-search-api/dev_guide/topics/endpoint-geocode-brief.html)

# %%
import requests
import random
import pandas as pd 
from tqdm import tqdm
from bs4  import BeautifulSoup
from _config import APIKEY_HERE_PLATFORM, TITLE_APP_HERE_PLATFORM
import json 
from tqdm import tqdm
import time
import datetime

import ast

# %%
df = pd.read_csv('Precios_Combustibles_Enero.csv')

# %%
'''
agente = Nombre_comercial
estado (A) = estado (1)
'''

df.head(2)
# Out:
#    departamentocodigo departamentonombre  municipiocodigo municipionombre  \
# 0                  63            QUINDIO            63001         ARMENIA
# 1                  63            QUINDIO            63001         ARMENIA
#
#                                               agente bandera  \
# 0  ESTACION DE SERVICIO AUTOMOTRIZ TERPEL CENTENARIO  TERPEL
# 1  ESTACION DE SERVICIO AUTOMOTRIZ TERPEL CENTENARIO  TERPEL
#
#               direccion                      producto  precio  estado  \
# 0  CARRERA 18 # 45 - 55               BIODIESEL EXTRA    8190       1
# 1  CARRERA 18 # 45 - 55  GASOLINA CORRIENTE OXIGENADA    8140       1
#
#             fecharegistro
# 0  01/02/2015 12:00:00 AM
# 1  01/02/2015 12:00:00 AM

# %% [markdown]
# # Clean Data

# %%
## Testing dates convertion

datetime.date.today().year

d = '01/02/2015 12:00:00 AM'

dt = datetime.datetime.strptime(d, '%m/%d/%Y %H:%M:%S %p')
dt.year
# Out:
# 2015

# %%
df['FechaRegistroDate'] = pd.to_datetime(df['fecharegistro'], format='%m/%d/%Y %H:%M:%S %p')
df[df['FechaRegistroDate'].dt.year == 2018]

# https://sparkbyexamples.com/pandas/pandas-extract-year-from-datetime/

# ['Mes'].max()
# Out:
#        departamentocodigo departamentonombre  municipiocodigo  \
# 555                    41              HUILA            41770
# 556                    81             ARAUCA            81794
# 557                    81             ARAUCA            81794
# 558                    41              HUILA            41770
# 559                    18            CAQUETA            18150
# ...                   ...                ...              ...
# 13569                  52             NARIÑO            52835
# 13570                   8          ATLANTICO             8001
# 13571                   8          ATLANTICO             8001
# 13572                  52             NARIÑO            52835
# 13573                   8          ATLANTICO             8001
#
#             municipionombre                                      agente  \
# 555                   SUAZA                       ESTACION BUENOS AIRES
# 556                    TAME        ESTACIÓN DE SERVICIO NUEVO SANTANDER
# 557                    TAME        ESTACIÓN DE SERVICIO NUEVO SANTANDER
# 558                   SUAZA                       ESTACION BUENOS AIRES
# 559    CARTAGENA DEL CHAIRA                        GASOLINERA EL CHAIRA
# ...                     ...                                         ...
# 13569                TUMACO  ESTADERO Y ESTACION DE SERVICIO LAS PALMAS
# 13570          BARRANQUILLA         ESTACION DE SERVICIO TERPEL PARAISO
# 13571          BARRANQUILLA         ESTACION DE SERVICIO TERPEL PARAISO
# 13572                TUMACO  ESTADERO Y ESTACION DE SERVICIO LAS PALMAS
# 13573          BARRANQUILLA         ESTACION DE SERVICIO TERPEL PARAISO
#
#       bandera                                direccion  \
# 555    TERPEL  VEREDA LIBANO CRUCE ACEVEDO - FLORENCIA
# 556    TERPEL     KILOMETRO 21 MAS 850 METROS VÍA TAME
# 557    TERPEL     KILOMETRO 21 MAS 850 METROS VÍA TAME
# 558    TERPEL  VEREDA LIBANO CRUCE ACEVEDO - FLORENCIA
# 559    TERPEL        CARRERA 4 No. 11-04 BARRIO GAITAN
# ...       ...                                      ...
# 13569  TERPEL          KILOMETRO 52 VIA TUMACO - PASTO
# 13570  TERPEL                       CALLE 76 No. 58-31
# 13571  TERPEL                       CALLE 76 No. 58-31
# 13572  TERPEL          KILOMETRO 52 VIA TUMACO - PASTO
# 13573  TERPEL                       CALLE 76 No. 58-31
#
#                            producto  precio  estado           fecharegistro  \
# 555                 BIODIESEL EXTRA    8136       1  01/02/2018 12:00:00 AM
# 556    GASOLINA CORRIENTE OXIGENADA    7100       1  01/02/2018 12:00:00 AM
# 557                 BIODIESEL EXTRA    6750       1  01/02/2018 12:00:00 AM
# 558    GASOLINA CORRIENTE OXIGENADA    8730       1  01/02/2018 12:00:00 AM
# 559                 BIODIESEL EXTRA    8860       1  01/03/2018 12:00:00 AM
# ...                             ...     ...     ...                     ...
# 13569               BIODIESEL EXTRA    7400       1  05/13/2018 12:00:00 AM
# 13570               BIODIESEL EXTRA    8450       1  05/13/2018 12:00:00 AM
# 13571      GASOLINA EXTRA OXIGENADA   11400       1  05/13/2018 12:00:00 AM
# 13572  GASOLINA CORRIENTE OXIGENADA    7550       1  05/13/2018 12:00:00 AM
# 13573  GASOLINA CORRIENTE OXIGENADA    8990       1  05/13/2018 12:00:00 AM
#
#         FechaRegistroDate
# 555   2018-01-02 12:00:00
# 556   2018-01-02 12:00:00
# 557   2018-01-02 12:00:00
# 558   2018-01-02 12:00:00
# 559   2018-01-03 12:00:00
# ...                   ...
# 13569 2018-05-13 12:00:00
# 13570 2018-05-13 12:00:00
# 13571 2018-05-13 12:00:00
# 13572 2018-05-13 12:00:00
# 13573 2018-05-13 12:00:00
#
# [13019 rows x 12 columns]

# %%
# df2 =  df[(df['Periodo']==2022) & (df['Mes']==6)]
df2 = df[(df['FechaRegistroDate'].dt.year == 2018) & (df['FechaRegistroDate'].dt.month == 5)]
df2
# Out:
#        departamentocodigo departamentonombre  municipiocodigo municipionombre  \
# 1203                   76    VALLE DEL CAUCA            76520         PALMIRA
# 1204                   66          RISARALDA            66400     LA VIRGINIA
# 1205                   13            BOLIVAR            13442   MARIA LA BAJA
# 1206                   11        BOGOTA D.C.            11001     BOGOTA D.C.
# 1207                   20              CESAR            20011       AGUACHICA
# ...                   ...                ...              ...             ...
# 13569                  52             NARIÑO            52835          TUMACO
# 13570                   8          ATLANTICO             8001    BARRANQUILLA
# 13571                   8          ATLANTICO             8001    BARRANQUILLA
# 13572                  52             NARIÑO            52835          TUMACO
# 13573                   8          ATLANTICO             8001    BARRANQUILLA
#
#                                                   agente    bandera  \
# 1203                     ESTACION DE SERVICIO SERVIBERNA      MOBIL
# 1204                    ESTACION DE SERVICIO LA VIRGINIA     BIOMAX
# 1205                                    EDS SAN JERONIMO     TERPEL
# 1206   ESTACION DE SERVICIO AUTOMOTRIZ PETROBRAS CALL...  PETROBRAS
# 1207                  ESTACION DE SERVICIO LOS COLUMPIOS     TERPEL
# ...                                                  ...        ...
# 13569         ESTADERO Y ESTACION DE SERVICIO LAS PALMAS     TERPEL
# 13570                ESTACION DE SERVICIO TERPEL PARAISO     TERPEL
# 13571                ESTACION DE SERVICIO TERPEL PARAISO     TERPEL
# 13572         ESTADERO Y ESTACION DE SERVICIO LAS PALMAS     TERPEL
# 13573                ESTACION DE SERVICIO TERPEL PARAISO     TERPEL
#
#                                      direccion                      producto  \
# 1203                        CARRERA 32 # 11-20  GASOLINA CORRIENTE OXIGENADA
# 1204                        CARRERA 8 No. 6-64      GASOLINA EXTRA OXIGENADA
# 1205          CORREGIMIENTO SENA MARIA LA BAJA               BIODIESEL EXTRA
# 1206                        CALLE 45 No. 16-30  GASOLINA CORRIENTE OXIGENADA
# 1207   KILOMETRO 5 VIA AGUACHICA - BUCARAMANGA  GASOLINA CORRIENTE OXIGENADA
# ...                                        ...                           ...
# 13569          KILOMETRO 52 VIA TUMACO - PASTO               BIODIESEL EXTRA
# 13570                       CALLE 76 No. 58-31               BIODIESEL EXTRA
# 13571                       CALLE 76 No. 58-31      GASOLINA EXTRA OXIGENADA
# 13572          KILOMETRO 52 VIA TUMACO - PASTO  GASOLINA CORRIENTE OXIGENADA
# 13573                       CALLE 76 No. 58-31  GASOLINA CORRIENTE OXIGENADA
#
#        precio  estado           fecharegistro   FechaRegistroDate
# 1203     8811       1  05/01/2018 12:00:00 AM 2018-05-01 12:00:00
# 1204    11600       1  05/01/2018 12:00:00 AM 2018-05-01 12:00:00
# 1205     7820       1  05/01/2018 12:00:00 AM 2018-05-01 12:00:00
# 1206     9230       1  05/01/2018 12:00:00 AM 2018-05-01 12:00:00
# 1207     7200       1  05/01/2018 12:00:00 AM 2018-05-01 12:00:00
# ...       ...     ...                     ...                 ...
# 13569    7400       1  05/13/2018 12:00:00 AM 2018-05-13 12:00:00
# 13570    8450       1  05/13/2018 12:00:00 AM 2018-05-13 12:00:00
# 13571   11400       1  05/13/2018 12:00:00 AM 2018-05-13 12:00:00
# 13572    7550       1  05/13/2018 12:00:00 AM 2018-05-13 12:00:00
# 13573    8990       1  05/13/2018 12:00:00 AM 2018-05-13 12:00:00
#
# [12371 rows x 12 columns]

# %%
df3 =  df2[(df2['departamentonombre']=='ANTIOQUIA') | (df2['departamentonombre']=='BOGOTA D.C.')]
df3
# Out:
#        departamentocodigo departamentonombre  municipiocodigo  \
# 1206                   11        BOGOTA D.C.            11001
# 1221                   11        BOGOTA D.C.            11001
# 1233                    5          ANTIOQUIA             5138
# 1236                   11        BOGOTA D.C.            11001
# 1243                    5          ANTIOQUIA             5315
# ...                   ...                ...              ...
# 13548                   5          ANTIOQUIA             5380
# 13554                   5          ANTIOQUIA             5854
# 13559                   5          ANTIOQUIA             5321
# 13563                  11        BOGOTA D.C.            11001
# 13568                   5          ANTIOQUIA             5615
#
#           municipionombre                                             agente  \
# 1206          BOGOTA D.C.  ESTACION DE SERVICIO AUTOMOTRIZ PETROBRAS CALL...
# 1221          BOGOTA D.C.          ESTACION DE SERVICIO AUTOMOTRIZ SANTANDER
# 1233          CAÑASGORDAS                                     LAS HELICONIAS
# 1236          BOGOTA D.C.                                  EDS BIOMAX TINTAL
# 1243            GUADALUPE                                    BOMBA LOS PINOS
# ...                   ...                                                ...
# 13548         LA ESTRELLA              ESTACION DE SERVICIO ESSO LA VARIANTE
# 13554            VALDIVIA                                  EDS PUERTO RAUDAL
# 13559             GUATAPE            ESTACIÓN DE SERVICIO ASTILLEROS GUATAPE
# 13563         BOGOTA D.C.                              ESTACION TEXACO No 25
# 13568  CANON DE RIO CLARO                                    AUTOCENTRO JBAM
#
#          bandera                             direccion  \
# 1206   PETROBRAS                    CALLE 45 No. 16-30
# 1221      TERPEL             CARRERA 27 No. 31C-63 SUR
# 1233       ZEUSS                       PARAJE IMANTAGO
# 1236      BIOMAX        AVENIDA CALLE 54 SUR No 89A-55
# 1243       ZEUSS              CALLE 51 A No 45-03   17
# ...          ...                                   ...
# 13548      MOBIL           CARRERA 48 No. 101 SUR -386
# 13554     TERPEL            KILOMETRO 22 PUERTO RAUDAL
# 13559     TEXACO  KILOMETRO 27 VÍA MARINILLA - GUATAPE
# 13563     TEXACO                CALLE 11 SUR No. 15-11
# 13568      MOBIL              Carrera 47 Calle 64A-125
#
#                            producto  precio  estado           fecharegistro  \
# 1206   GASOLINA CORRIENTE OXIGENADA    9230       1  05/01/2018 12:00:00 AM
# 1221                BIODIESEL EXTRA    7986       1  05/01/2018 12:00:00 AM
# 1233   GASOLINA CORRIENTE OXIGENADA    9060       1  05/01/2018 12:00:00 AM
# 1236                  BIOACEM AL 9%    8110       1  05/01/2018 12:00:00 AM
# 1243                BIODIESEL EXTRA    8810       1  05/01/2018 12:00:00 AM
# ...                             ...     ...     ...                     ...
# 13548  GASOLINA CORRIENTE OXIGENADA    8620       1  05/12/2018 12:00:00 AM
# 13554               BIODIESEL EXTRA    8179       1  05/12/2018 12:00:00 AM
# 13559  GASOLINA CORRIENTE OXIGENADA    9090       1  05/12/2018 12:00:00 AM
# 13563               BIODIESEL EXTRA    8350       1  05/12/2018 12:00:00 AM
# 13568               BIODIESEL EXTRA    8515       1  05/12/2018 12:00:00 AM
#
#         FechaRegistroDate
# 1206  2018-05-01 12:00:00
# 1221  2018-05-01 12:00:00
# 1233  2018-05-01 12:00:00
# 1236  2018-05-01 12:00:00
# 1243  2018-05-01 12:00:00
# ...                   ...
# 13548 2018-05-12 12:00:00
# 13554 2018-05-12 12:00:00
# 13559 2018-05-12 12:00:00
# 13563 2018-05-12 12:00:00
# 13568 2018-05-12 12:00:00
#
# [2605 rows x 12 columns]

# %%
df3['municipionombre'].value_counts().head(10)
# Out:
# municipionombre
# BOGOTA D.C.           1278
# MEDELLIN               305
# BELLO                   59
# ITAGUI                  53
# CANON DE RIO CLARO      48
# ENVIGADO                46
# CAUCASIA                28
# SABANETA                27
# TURBO                   25
# COPACABANA              25
# Name: count, dtype: int64

# %%
df4 = df3[(df3['departamentonombre']=='BOGOTA D.C.') | ((df3['departamentonombre']=='ANTIOQUIA') & ((df3['municipionombre']=='MEDELLIN') | (df3['municipionombre']=='ITAGUI') | (df3['municipionombre']=='BELLO') | (df3['municipionombre']=='SABANETA') | (df3['municipionombre']=='RIONEGRO') | (df3['municipionombre']=='ENVIGADO')))]
df4.reset_index(inplace = True)
df4.drop(columns = 'index',inplace = True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21420\401858228.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.drop(columns = 'index',inplace = True)

# %%
df4.head(2)
# Out:
#    departamentocodigo departamentonombre  municipiocodigo municipionombre  \
# 0                  11        BOGOTA D.C.            11001     BOGOTA D.C.
# 1                  11        BOGOTA D.C.            11001     BOGOTA D.C.
#
#                                               agente    bandera  \
# 0  ESTACION DE SERVICIO AUTOMOTRIZ PETROBRAS CALL...  PETROBRAS
# 1          ESTACION DE SERVICIO AUTOMOTRIZ SANTANDER     TERPEL
#
#                    direccion                      producto  precio  estado  \
# 0         CALLE 45 No. 16-30  GASOLINA CORRIENTE OXIGENADA    9230       1
# 1  CARRERA 27 No. 31C-63 SUR               BIODIESEL EXTRA    7986       1
#
#             fecharegistro   FechaRegistroDate
# 0  05/01/2018 12:00:00 AM 2018-05-01 12:00:00
# 1  05/01/2018 12:00:00 AM 2018-05-01 12:00:00

# %%
df4['departamentonombre'].unique()
# Out:
# array(['BOGOTA D.C.', 'ANTIOQUIA'], dtype=object)

# %%
df4['Dir2'] = df4['direccion'].apply(lambda x : x.replace('#','No'))
df4['Full_Address'] = df4.apply(lambda x : x['Dir2'] + ', ' + x['municipionombre'].capitalize() + ', Colombia' , axis = 1)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21420\1069916494.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Dir2'] = df4['direccion'].apply(lambda x : x.replace('#','No'))
# C:\Users\pc\AppData\Local\Temp\ipykernel_21420\1069916494.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Full_Address'] = df4.apply(lambda x : x['Dir2'] + ', ' + x['municipionombre'].capitalize() + ', Colombia' , axis = 1)

# %%
df4['Full_Address'].nunique()
# Out:
# 558

# %%
df4['Full_Address'][0]
# Out:
# 'CALLE 45 No. 16-30, Bogota d.c., Colombia'

# %%
estaciones =  df4[['agente','Dir2','Full_Address']].drop_duplicates(subset = 'agente')
estaciones.reset_index(inplace = True)
estaciones.drop(columns = 'index',inplace = True)

# %%
estaciones['Full_Address'][0]
# Out:
# 'CALLE 45 No. 16-30, Bogota d.c., Colombia'

# %%
address = estaciones['Full_Address'][0]
url = f'https://geocode.search.hereapi.com/v1/geocode?q={address}&apiKey={APIKEY_HERE_PLATFORM}'
response = requests.get(url).json()

# %%
response
# Out:
# {'items': [{'title': 'Avenida Calle 45 9-16, 110231 Bogotá, D.C., Colombia',
#    'id': 'here:af:streetsection:CUj62WNnCkoYmZxg95FwnA:EAIaAjE2',
#    'resultType': 'houseNumber',
#    'houseNumberType': 'interpolated',
#    'address': {'label': 'Avenida Calle 45 9-16, 110231 Bogotá, D.C., Colombia',
#     'countryCode': 'COL',
#     'countryName': 'Colombia',
#     'countyCode': 'DC',
#     'county': 'Bogotá, D.C.',
#     'city': 'Bogotá, D.C.',
#     'district': 'Chapinero',
#     'street': 'Avenida Calle 45 9',
#     'postalCode': '110231',
#     'houseNumber': '16'},
#    'position': {'lat': 4.63204, 'lng': -74.06546},
#    'access': [{'lat': 4.63191, 'lng': -74.0655}],
#    'mapView': {'west': -74.06636,
#     'south': 4.63114,
#     'east': -74.06456,
#     'north': 4.63294},
#    'scoring': {'queryScore': 0.9,
#     'fieldScore': {'country': 1.0,
#      'city': 1.0,
#      'streets': [0.85],
#      'houseNumber': 1.0}}},
#   {'title': 'Calle 16-30, 110321 Bogotá, D.C., Colombia',
#    'id': 'here:af:streetsection:bbKO2BHKtDta7HEFzbMp7A:EAIaAjMw',
#    'resultType': 'houseNumber',
#    'houseNumberType': 'interpolated',
#    'address': {'label': 'Calle 16-30, 110321 Bogotá, D.C., Colombia',
#     'countryCode': 'COL',
#     'countryName': 'Colombia',
#     'countyCode': 'DC',
#     'county': 'Bogotá, D.C.',
#     'city': 'Bogotá, D.C.',
#     'district': 'Santa Fé',
#     'street': 'Calle 16',
#     'postalCode': '110321',
#     'houseNumber': '30'},
#    'position': {'lat': 4.60228, 'lng': -74.07204},
#    'access': [{'lat': 4.60217, 'lng': -74.07211}],
#    'mapView': {'west': -74.07294,
#     'south': 4.60138,
#     'east': -74.07114,
#     'north': 4.60318},
#    'scoring': {'queryScore': 0.69,
#     'fieldScore': {'country': 1.0,
#      'city': 1.0,
#      'streets': [0.9],
#      'houseNumber': 1.0}}}]}

# %%
def Get_Coords(address,apikey):
    
    url = f'https://geocode.search.hereapi.com/v1/geocode?q={address}&apiKey={apikey}'
    
    try : 
        
        response = requests.get(url).json()
        CleanAddress = response['items'][0]['title'].upper()
        LAT = response['items'][0]['position']['lat']
        LNG = response['items'][0]['position']['lng']
        
        results = [CleanAddress,LAT,LNG]
        
    except :
        
        results = ['Not Found','NA','NA']
        
    
    return results

# %%
Get_Coords(address,APIKEY_HERE_PLATFORM)
# Out:
# ['AVENIDA CALLE 45 9-16, 110231 BOGOTÁ, D.C., COLOMBIA', 4.63204, -74.06546]

# %% [markdown]
# # Extracción de coordenadas

# %%
coordenadas = []
tiempo = [1,2,2.5]

for i in tqdm(range(len(estaciones['Full_Address'])),colour = 'green'):
    
    try :
        
        R = Get_Coords(estaciones['Full_Address'][i],APIKEY_HERE_PLATFORM)
        geo_source = R[1],R[2]
        coordenadas.append(geo_source)
        
    except :
        
        coordenadas.append('Error')
        
    
    time.sleep(random.choices(tiempo)[0])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████|
#  (6.26939, -75.57407),
#  (4.65932, -74.05932),
#  (4.76895, -74.02372),
#  (4.60412, -74.06736),
#  (6.22804, -75.57211),
#  (4.73051, -74.02842),
#  (4.60391, -74.12033),
#  (6.32743, -75.54308),
#  (4.67395, -74.10592),
#  (4.69434, -74.12281),
#  (6.2581, -75.58618),
#  (4.57522, -74.15471),
#  (6.2488, -75.56001),
#  (4.58869, -74.115),
#  (4.71627, -74.06041),
#  (6.40563, -75.60017),
#  (4.581, -74.08614),
#  (6.17104, -75.62726),
#  (4.61265, -74.07066),
#  (6.20994, -75.56904),
#  (6.17933, -75.57791),
#  (4.59233, -74.08853),
#  (6.16289, -75.5456),
#  (6.18193, -75.61053),
#  (6.26057, -75.56887),
#  (6.27572, -75.5729),
#  (6.23189, -75.59976),
#  (4.62941, -74.19503),
#  (4.58132, -74.09342),
#  (6.18076, -75.59176),
#  (4.68872, -74.16241),
#  (4.69737, -74.10489),
#  (6.29711, -75.54312),
#  (6.23224, -75.59122),
#  (4.65599, -74.05509),
#  (6.28006, -75.56187),
#  (4.57894, -74.08693),
#  (6.17853, -75.63805),
#  (4.60916, -74.06741),
#  (6.17958, -75.59242),
#  (4.74769, -74.05695),
#  (4.67775, -74.14998),
#  (4.66937, -74.15793),
#  (6.1665, -75.61792),
#  (6.14546, -75.62123),
#  (4.65303, -74.11627),
#  (4.59693, -74.11292),
#  (4.54922, -74.137),
#  (6.24716, -75.62251),
#  (6.16239, -75.61453),
#  (4.62183, -74.11015),
#  (4.73265, -74.0563),
#  (4.64171, -74.07206),
#  (4.72372, -74.0629),
#  (4.62693, -74.10797),
#  (4.60435, -74.10094),
#  (6.25802, -75.56781),
#  (6.24183, -75.58214),
#  (4.58965, -74.1497),
#  (4.66606, -74.07489),
#  (4.68385, -74.14214),
#  (4.54668, -74.08707),
#  ('NA', 'NA'),
#  (4.67463, -74.06666),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA'),
#  ('NA', 'NA')]

# %%
estaciones['Coords'] = coordenadas

# %%
estaciones
# Out:
#                                                 agente  \
# 0    ESTACION DE SERVICIO AUTOMOTRIZ PETROBRAS CALL...
# 1            ESTACION DE SERVICIO AUTOMOTRIZ SANTANDER
# 2                                    EDS BIOMAX TINTAL
# 3                  ESTACION DE SERVICIO ESPERANZA BOSA
# 4                                      EDS LOS ABUELOS
# ..                                                 ...
# 552              ESTACION DE SERVICIO PETROBRAS IBERIA
# 553                               ESTACION BRIO IBERIA
# 554                  ESTACION DE SERVICIO TERPEL LA 45
# 555                               EDS ESSO BOLIVARIANA
# 556                              ESTACION TEXACO No 25
#
#                                Dir2  \
# 0                CALLE 45 No. 16-30
# 1         CARRERA 27 No. 31C-63 SUR
# 2    AVENIDA CALLE 54 SUR No 89A-55
# 3             CARRERA 79 No. 74D-11
# 4           CALLE 170 No. 20 A - 34
# ..                              ...
# 552     AVENIDA CALLE 134 No. 53-51
# 553            CALLE 134A No. 53-85
# 554            CARRERA 45 No. 66-10
# 555           AVENIDA 33 No. 66A-21
# 556          CALLE 11 SUR No. 15-11
#
#                                           Full_Address                Coords
# 0            CALLE 45 No. 16-30, Bogota d.c., Colombia  (4.63204, -74.06546)
# 1     CARRERA 27 No. 31C-63 SUR, Bogota d.c., Colombia  (4.59549, -74.10256)
# 2    AVENIDA CALLE 54 SUR No 89A-55, Bogota d.c., C...     (4.6322, -74.185)
# 3         CARRERA 79 No. 74D-11, Bogota d.c., Colombia  (4.60867, -74.20333)
# 4       CALLE 170 No. 20 A - 34, Bogota d.c., Colombia  (4.75082, -74.04352)
# ..                                                 ...                   ...
# 552  AVENIDA CALLE 134 No. 53-51, Bogota d.c., Colo...              (NA, NA)
# 553        CALLE 134A No. 53-85, Bogota d.c., Colombia              (NA, NA)
# 554           CARRERA 45 No. 66-10, Medellin, Colombia              (NA, NA)
# 555          AVENIDA 33 No. 66A-21, Medellin, Colombia              (NA, NA)
# 556      CALLE 11 SUR No. 15-11, Bogota d.c., Colombia              (NA, NA)
#
# [557 rows x 4 columns]

# %%
len(df4)
# Out:
# 1768

# %%
estaciones.head(2)
# Out:
#                                               agente  \
# 0  ESTACION DE SERVICIO AUTOMOTRIZ PETROBRAS CALL...
# 1          ESTACION DE SERVICIO AUTOMOTRIZ SANTANDER
#
#                         Dir2  \
# 0         CALLE 45 No. 16-30
# 1  CARRERA 27 No. 31C-63 SUR
#
#                                        Full_Address                Coords
# 0         CALLE 45 No. 16-30, Bogota d.c., Colombia  (4.63204, -74.06546)
# 1  CARRERA 27 No. 31C-63 SUR, Bogota d.c., Colombia  (4.59549, -74.10256)

# %%
df_final = pd.merge(df4,estaciones[['Full_Address','Coords']],how = 'inner' , on = 'Full_Address')

# %%
df_final.head(3)
# Out:
#    departamentocodigo departamentonombre  municipiocodigo municipionombre  \
# 0                  11        BOGOTA D.C.            11001     BOGOTA D.C.
# 1                  11        BOGOTA D.C.            11001     BOGOTA D.C.
# 2                  11        BOGOTA D.C.            11001     BOGOTA D.C.
#
#                                               agente    bandera  \
# 0  ESTACION DE SERVICIO AUTOMOTRIZ PETROBRAS CALL...  PETROBRAS
# 1  ESTACION DE SERVICIO AUTOMOTRIZ PETROBRAS CALL...  PETROBRAS
# 2  ESTACION DE SERVICIO AUTOMOTRIZ PETROBRAS CALL...  PETROBRAS
#
#             direccion                      producto  precio  estado  \
# 0  CALLE 45 No. 16-30  GASOLINA CORRIENTE OXIGENADA    9230       1
# 1  CALLE 45 No. 16-30               BIODIESEL EXTRA    8440       1
# 2  CALLE 45 No. 16-30                 BIOACEM AL 9%    8440       1
#
#             fecharegistro   FechaRegistroDate                Dir2  \
# 0  05/01/2018 12:00:00 AM 2018-05-01 12:00:00  CALLE 45 No. 16-30
# 1  05/01/2018 12:00:00 AM 2018-05-01 12:00:00  CALLE 45 No. 16-30
# 2  05/01/2018 12:00:00 AM 2018-05-01 12:00:00  CALLE 45 No. 16-30
#
#                                 Full_Address                Coords
# 0  CALLE 45 No. 16-30, Bogota d.c., Colombia  (4.63204, -74.06546)
# 1  CALLE 45 No. 16-30, Bogota d.c., Colombia  (4.63204, -74.06546)
# 2  CALLE 45 No. 16-30, Bogota d.c., Colombia  (4.63204, -74.06546)

# %%
df_final.to_csv('DATASET_FINAL.CSV',index = False)
