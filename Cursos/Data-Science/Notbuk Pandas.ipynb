# %%
import pandas as pd

# %%
obj = pd.Series([4,7,-5,3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
animales = ["tortuga", "Zorro", "Liberal", "Paloma", "Efelante"]
tipo = ["reptil","mamífero","imbécil","ave","mamífero"]
obj = pd.Series(tipo, index = animales)
obj
# Out:
# tortuga       reptil
# Zorro       mamífero
# Liberal      imbécil
# Paloma           ave
# Efelante    mamífero
# dtype: object

# %% [markdown]
# # Data Frames

# %%
df = pd.read_csv('fifa-statistics.csv')
df
# Out:
#      Game                     Group          Team      Opponent Home/Away  \
# 0       1                         A        Russia  Saudi Arabia      home
# 1       1                         A  Saudi Arabia        Russia      away
# 2       2                         A         Egypt       Uruguay      home
# 3       2                         A       Uruguay         Egypt      away
# 4       3                         B       Morocco       IR Iran      home
# ..    ...                       ...           ...           ...       ...
# 123    62               Semi-finals       England       Croatia      away
# 124    63  Play-off for third place       Belgium       England      home
# 125    63  Play-off for third place       England       Belgium      away
# 126    64                     Final        France       Croatia      home
# 127    64                     Final       Croatia        France      away
#
#     Score WDL Pens?  Goals For  Goals Against  ...  Passes Completed  \
# ...

# %%
df.loc[0, 'Team'] # Trae de la columna "Team", de la fila cero
df.loc[0:11, 'Team']
df.iloc[0, [1]] #Trae de la columna número 1, de la fila cero
df.iloc[2]
# Out:
# Game                                            2
# Group                                           A
# Team                                        Egypt
# Opponent                                  Uruguay
# Home/Away                                    home
# Score                                         0-1
# WDL                                             L
# Pens?                                         NaN
# Goals For                                       0
# Goals Against                                   1
# Pen Shootout For                              NaN
# Pen Shootout Against                          NaN
# Attempts                                        8
# On-Target                                       3
# Off-Target                                      3
# Blocked                                         2
# Woodwork                                        0
# Corners                                         0
# Offsides                                        1
# ...

# %% [markdown]
# # Análisis descriptivo de los datos

# %%
df.describe()
df.info()
df.shape
df.columns
df.head(4)
df.tail(4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 32 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Game                                    128 non-null    int64
#  1   Group                                   128 non-null    object
#  2   Team                                    128 non-null    object
#  3   Opponent                                128 non-null    object
#  4   Home/Away                               128 non-null    object
#  5   Score                                   128 non-null    object
#  6   WDL                                     128 non-null    object
#  7   Pens?                                   8 non-null      object
#  8   Goals For                               128 non-null    int64
#  9   Goals Against                           128 non-null    int64
# ...

# %%
df.Team.unique()
# Out:
# array(['Russia', 'Saudi Arabia', 'Egypt', 'Uruguay', 'Morocco', 'IR Iran',
#        'Portugal', 'Spain', 'France', 'Australia', 'Argentina', 'Iceland',
#        'Peru', 'Denmark', 'Croatia', 'Nigeria', 'Costa Rica', 'Serbia',
#        'Germany', 'Mexico', 'Brazil', 'Switzerland', 'Sweden',
#        'Korea Republic', 'Belgium', 'Panama', 'Tunisia', 'England',
#        'Colombia', 'Japan', 'Poland', 'Senegal'], dtype=object)

# %%
df.Team.value_counts()
# Out:
# Belgium           7
# England           7
# France            7
# Croatia           7
# Uruguay           5
# Sweden            5
# Brazil            5
# Russia            5
# Mexico            4
# Colombia          4
# Switzerland       4
# Spain             4
# Japan             4
# Argentina         4
# Denmark           4
# Portugal          4
# Panama            3
# Iceland           3
# Saudi Arabia      3
# Poland            3
# Germany           3
# Senegal           3
# IR Iran           3
# Tunisia           3
# Australia         3
# Egypt             3
# Nigeria           3
# Korea Republic    3
# Morocco           3
# Peru              3
# Costa Rica        3
# Serbia            3
# Name: Team, dtype: int64

# %% [markdown]
# # ESTADÍSTICOS

# %%
df.mean()

# Percentiles

df["Distance Covered km"].quantile(0.10)
df.sort_values(by=["Distance Covered km"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-4fe9a11a6d41> in <module>
#       4
#       5 df["Distance Covered km"].quantile(0.10)
# ----> 6 df.sort_index(by=["Distance Covered km"])
#
# TypeError: sort_index() got an unexpected keyword argument 'by'

# %%
# Apply
