# %%
# pip install chromadb==0.5.5 --force-reinstall
# pip install numpy==1.24.3 --force-reinstall

# %%
import chromadb
import json
import openai

from openai import OpenAI

from chromadb.utils import embedding_functions
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction

from chromadb import Client
from chromadb.config import Settings

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
embedding_model_name = "all-mpnet-base-v2" # text-embedding-ada-002
openAI_embedding_model_name = "text-embedding-ada-002"

chroma_user = os.getenv("CHROMA_USER")
chroma_pass = os.getenv("CHROMA_PASS")
chroma_host = os.getenv("CHROMA_HOST")
chroma_port = os.getenv("CHROMA_PORT")
open_AI_APIKey = os.getenv("CHROMA_OPENAI_API_KEY")

n_results = 5

user_query = "Solo sé que no sé nada"
query = [user_query]

# %%
print(chroma_user)
print(chroma_pass)
print(chroma_host)
print(chroma_port)
# Out:
# chroma
# lueBAQBbCZZOiHLj
# chromadb.reto-ucu.net
# 50004

# %%
openai_ef = OpenAIEmbeddingFunction(
    model_name = openAI_embedding_model_name
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 openai_ef = OpenAIEmbeddingFunction(
#       2     model_name = openAI_embedding_model_name
#       3 )
#
# File ~\anaconda3\envs\rag-env\lib\site-packages\chromadb\utils\embedding_functions\openai_embedding_function.py:53, in OpenAIEmbeddingFunction.__init__(self, api_key, model_name, organization_id, api_base, api_type, api_version, deployment_id, default_headers)
#      51 # If the api key is still not set, raise an error
#      52 elif openai.api_key is None:
# ---> 53     raise ValueError(
#      54         "Please provide an OpenAI API key. You can get one at https://platform.openai.com/account/api-keys"
#      55     )
#      57 if api_base is not None:
#      58     openai.api_base = api_base
#
# ...

# %%
import base64
import chromadb

auth_string = f"{chroma_user}:{chroma_pass}"
encoded_auth = base64.b64encode(auth_string.encode()).decode()

client = chromadb.HttpClient(
    host=chroma_host,
    port=chroma_port,
    headers={
        "Authorization": f"Basic {encoded_auth}"
    }
)
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given

# %%
encoded_auth
# Out:
# 'Y2hyb21hOmx1ZUJBUUJiQ1paT2lITGo='

# %%
collection = client.get_or_create_collection("my_collection")

# %%
# Out:
# ...
#   Using cached build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# ...
#   Using cached fastapi-0.116.1-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached posthog-6.4.1-py3-none-any.whl.metadata (6.0 kB)
# ...
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached onnxruntime-1.22.1-cp310-cp310-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached opentelemetry_api-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached opentelemetry_instrumentation_fastapi-0.57b0-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached opentelemetry_sdk-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached tokenizers-0.21.4-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# ...
#   Using cached pypika-0.48.9-py2.py3-none-any.whl
# ...

# %%
import chromadb
print(chromadb.__version__)
# Out:
# 0.5.5

# %%
client.list_collections()
# Out:
# [Collection(id=26fea393-f946-4f04-a801-d78d7fff3ddd, name=prueba_coleccion_all_mpnet_base_v2),
#  Collection(id=2ff21694-609e-49c3-9a42-febf9a9b0b19, name=documentos_coty),
#  Collection(id=3756802d-b5cb-4be5-b3cf-9fe74cb0bd56, name=tomas2),
#  Collection(id=37a940e6-b00e-4de8-a183-f35671f6e3d3, name=prueba_coleccion_all_MiniLM_L6_v2),
#  Collection(id=43b37ab9-a958-4f9b-83b2-453808aedc09, name=prueba_coleccion_paraphrase_MiniLM_L3_v2),
#  Collection(id=47d1517b-f796-40c0-b94d-b4e32bfcfc99, name=random),
#  Collection(id=5066cfec-cadc-4693-b7e5-6d79524d97d9, name=tomas),
#  Collection(id=5e318bda-7024-42d6-9ffe-776ff0142a3f, name=prueba_coleccion_paraphrase_multilingual_MiniLM_L12_v2),
#  Collection(id=662e70fb-9214-4b20-a1cd-ade97575bec9, name=mi_coleccion),
#  Collection(id=6a87944d-686f-44be-aa11-171e87c287ab, name=documents),
#  Collection(id=76bedff9-8fcc-447e-ab49-27e409bb2084, name=philosophy_quotes2),
# ...

# %%
# Out:
# ...
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ------ --------------------------------- 2.4/14.8 MB 13.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.0/14.8 MB 15.4 MB/s eta 0:00:01
#    --------------------------- ------------ 10.2/14.8 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.8 MB 18.5 MB/s eta 0:00:01
#    ---------------------------------------- 14.8/14.8 MB 17.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'C:\Users\Admin\anaconda3\envs\rag-env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.24.3

# %%
auth_string = f"{chroma_user}:{chroma_pass}"

chroma_client = chromadb.HttpClient(
    host=chroma_host,
    port=50004,
    settings= Settings(
        chroma_client_auth_provider="chromadb.auth.basic_authn.BasicAuthClientProvider",
        chroma_client_auth_credentials = auth_string
    ))

#chroma_client = Client(settings)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~\anaconda3\envs\rag-env\lib\site-packages\chromadb\api\base_http_client.py:100, in BaseHTTPClient._raise_chroma_error(resp)
#      99 try:
# --> 100     resp.raise_for_status()
#     101 except httpx.HTTPStatusError:
#
# File ~\anaconda3\envs\rag-env\lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '404 Not Found' for url 'https://chromadb.reto-ucu.net/api/v2/auth/identity'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/404
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ...

# %%
import chromadb

chroma_client = chromadb.HttpClient(host="chromadb.reto-ucu.net", port=50004)
collection = chroma_client.get_or_create_collection("my_collection")

# %%
lala = chroma_client.list_collections()
